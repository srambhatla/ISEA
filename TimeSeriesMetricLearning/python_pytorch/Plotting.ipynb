# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
import seaborn as sns
import pandas as pd

# %%
acc = {}
std = {}

# Decade
#acc['Decade'] = [0.930,	0.933, 0.93, 0.927, 0.930, 0.930, 0.930, 0.927, 0.928, 0.928]
#std['Decade'] = [0.021,	0.031, 0.029, 0.031, 0.032, 0.030, 0.030, 0.033, 0.034, 0.030]

#Decade fixed(May)
acc['Decade'] = [0.946, 0.951, 0.951, 0.946, 0.945, 0.946, 0.946, 0.945, 0.943, 0.941]
std['Decade'] =  [0.015, 0.02, 0.02, 0.017, 0.021,  0.019, 0.019, 0.019, 0.018, 0.018]

# Decade -IS 32_48_10_3_10_0.5
#acc['I-SEA'] = [0.937, 0.942, 0.943, 0.942, 0.937, 0.938, 0.937, 0.938, 0.935, 0.932]
#std['I-SEA'] = [0.015, 0.021, 0.019, 0.017, 0.022, 0.023, 0.015, 0.017, 0.014, 0.018]

# ISEA KDE 32_48_10_1
acc['I-SEA (WIS-KDE)'] = [0.955, 0.955, 0.955, 0.952, 0.953, 0.952, 0.952, 0.948, 0.948, 0.948]
std['I-SEA (WIS-KDE)'] =  [0.016, 0.015, 0.015, 0.016, 0.018, 0.020, 0.020, 0.022, 0.022, 0.022]


#acc['I-SEA-2'] = [0.936, 0.94, 0.941, 0.941, 0.938, 0.938, 0.938, 0.938, 0.936, 0.936]
#std['I-SEA-2'] = [0.023, 0.024, 0.023, 0.023, 0.026, 0.026, 0.026, 0.026, 0.027, 0.027]

acc['I-SEA (WIS-Unif)'] = [0.950, 0.955, 0.953, 0.950, 0.950, 0.950, 0.950, 0.945, 0.945, 0.948]
std['I-SEA (WIS-Unif)'] = [0.017, 0.009, 0.01, 0.009, 0.011, 0.014, 0.014, 0.014, 0.014, 0.016]


acc['Soft-DTW'] = [0.916, 0.906, 0.906, 0.913, 0.911, 0.911, 0.911, 0.910, 0.908, 0.910]
std['Soft-DTW'] = [0.014, 0.010, 0.010, 0.012, 0.012, 0.015, 0.015, 0.016, 0.017, 0.012]

# DTW-C MDTW-NN
#hid_rep = 0.5
acc['MDTW-NN'] = [0.905, 0.910, 0.912, 0.918, 0.917, 0.913, 0.908, 0.915, 0.913, 0.917]
std['MDTW-NN'] = [0.025, 0.026, 0.024, 0.019, 0.019, 0.019, 0.022, 0.026, 0.027, 0.026]
# hid_rep = 1.0
# acc['MDTW-NN'] = [0.915, 0.930, 0.932, 0.928, 0.932, 0.927, 0.928, 0.928, 0.922, 0.925]
# std['MDTW-NN'] = [0.026, 0.020, 0.037, 0.036, 0.033, 0.032, 0.019, 0.020, 0.021, 0.018] 

# Manhattan
# hid_rep = 0.5
acc['Ma-NN'] = [0.913, 0.910, 0.915, 0.912, 0.907, 0.905, 0.908, 0.907, 0.908, 0.910]
std['Ma-NN'] =  [0.017, 0.024, 0.021, 0.026, 0.031, 0.030, 0.032, 0.035, 0.035, 0.036]

# hid_rep = 1.0
#acc['MaLSTM'] = [0.928, 0.943, 0.937, 0.935,  0.935, 0.935, 0.933, 0.932, 0.928, 0.927]
#std['MaLSTM'] = [0.028, 0.024, 0.028, 0.030, 0.025,  0.024, 0.023, 0.024, 0.026, 0.025 ]

#acc['Ma-LSTM'] = [0.886, 0.8850, 0.883, 0.885, 0.883, 0.881, 0.883, 0.885, 0.883, 0.881]
#std['Ma-LSTM'] =[0.035, 0.025, 0.024, 0.018, 0.019, 0.020, 0.019, 0.017, 0.019, 0.020]

# MDTW
acc['MDTW'] = [0.723, 0.690, 0.685, 0.667, 0.655, 0.637, 0.617, 0.612, 0.595, 0.597]
std['MDTW'] = [0.022, 0.030, 0.037, 0.035, 0.025, 0.032, 0.020, 0.030, 0.032, 0.019]

# GAK
acc['GAK'] = [0.717, 0.702, 0.677, 0.677, 0.663, 0.638, 0.632, 0.627, 0.608, 0.588]
std['GAK'] = [0.026, 0.036, 0.022, 0.043, 0.037, 0.033, 0.043, 0.030, 0.026, 0.021]

# LDMLT-TS
acc['LDMLT'] = [0.677, 0.613, 0.592, 0.568, 0.542, 0.540, 0.530, 0.523, 0.520, 0.515]
std['LDMLT'] = [0.034, 0.042, 0.059, 0.068, 0.070, 0.068, 0.073, 0.078, 0.074, 0.072]

# Tree-MSA
acc['MSA'] = [0.680, 0.648, 0.617, 0.583, 0.583, 0.568, 0.567, 0.560, 0.553, 0.542]
std['MSA'] = [0.037, 0.028, 0.026, 0.026, 0.037, 0.050, 0.044, 0.040, 0.048, 0.033]

# %%
res_line = ''
met = 'Decade'
for i in range(0,10):
    res_line = res_line + ' & $ ' + str(acc[met][i]) + ' \pm ' + str(std[met][i]) + ' $ ' 
print(res_line)
# Out:
#  & $ 0.946 \pm 0.015 $  & $ 0.951 \pm 0.02 $  & $ 0.951 \pm 0.02 $  & $ 0.946 \pm 0.017 $  & $ 0.945 \pm 0.021 $  & $ 0.946 \pm 0.019 $  & $ 0.946 \pm 0.019 $  & $ 0.945 \pm 0.019 $  & $ 0.943 \pm 0.018 $  & $ 0.941 \pm 0.018 $

# %%
# import matplotlib.ticker as mtick
# from matplotlib import pyplot
# import matplotlib as mlib
# #methods = ['I-SEA','Decade', 'MDTW-NN', 'MaLSTM', 'MDTW', 'GAK', 'TMSA','LDMLT']
# methods = ['I-SEA', 'I-SEA-Naive', 'Decade', 'Soft-DTW-NN', 'MDTW-NN', 'Ma-NN', 'Soft-DTW-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
# marker = itertools.cycle(("<", "o", "v", "s", "D", "X", "d", "*","h", "x","+","P","H", '^', ">")) 
# lstyle = itertools.cycle(('--', '-.', ':'))
# lcolor = itertools.cycle(('black', 'red', 'cyan', 'magenta', 'brown', 'lime', 'blue', 'green', 'orange'))

# ax = plt.axes()

# for key in methods:
#     val = 0.5*np.random.rand(1)
#     ax.semilogy(np.arange(1,20, 2),(1 - np.array(acc[key])), marker = next(marker), 
#              linestyle=next(lstyle), linewidth=2, markersize=8, color=next(lcolor))#color=str(val.item()))
# ax.legend(methods, loc='center left', bbox_to_anchor= (1.0, 0.72))

# ax.set_yscale('log')
# plt.tick_params(axis='y', which='minor')

# #plt.setp( ax.get_yticklabels(), visible=True)
# ax.yaxis.set_minor_formatter(plt.NullFormatter())
# ax.yaxis.set_minor_formatter(plt.FormatStrFormatter("%.2f"))
# ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%0.2f'))

# ax.xaxis.set_major_locator(mlib.ticker.FixedLocator(np.arange(1,20,2)))


# # print(ymin, ymax)
# ax.set_ylabel('Misclassification',fontsize=14)
# ax.set_xlabel('K-Nearest Neighbors',fontsize=14)

# ax.tick_params(axis='both', which='major', labelsize=12,  length=4)
# ax.tick_params(axis='both', which='minor', labelsize=12, length=4)
# plt.grid(which='both')

# #plt.savefig('../python_pytorch/results/eeg/plots/eeg_misclass_updated_Feb_3.pdf', format='pdf',bbox_inches='tight')
# #plt.savefig('../python_pytorch/results/eeg-new-mis.eps',  format='eps')

# %%
import matplotlib.ticker as mtick
from matplotlib import pyplot
import matplotlib as mlib
from matplotlib.pyplot import figure

#methods = ['I-SEA', 'I-SEA-Naive', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
marker = itertools.cycle(("<", "o", "v", "s", "D", "X", "d", "*","h", "x","^","P","H", '+', ">")) 
lstyle = itertools.cycle(('--', '-.', ':'))
lcolor = itertools.cycle(('black', 'red', 'cyan', 'magenta', 'brown', 'lime', 'blue', 'green', 'orange', 'purple', 'darkblue'))
figure(figsize=(11, 6))
color_dict = {}
ax = plt.axes()
i = 1
for key in methods:
    val = 0.5*np.random.rand(1)
    cl = next(lcolor)
    if cl == 'black':
        color_dict[key] = 'gray'
    else:
        color_dict[key] = cl
    ax.semilogy(np.arange(1,20, 2),(1 - np.array(acc[key])), marker = next(marker), 
             linestyle=next(lstyle), linewidth=2, markersize=10, color=cl)#color=str(val.item()))
    #if key == 'I-SEA' or key == 'Decade' or key == 'LDMLT':
    #    ax.fill_between(np.arange(1,20, 2), (1 - np.array(acc[key]))-std[key], (1 - np.array(acc[key]))+std[key], alpha = 0.6 - 0.15*i, color=cl)
    #    i = i + 1
ax.legend(methods, loc='center left', bbox_to_anchor= (1, 0.64), fontsize=16)

ax.set_yscale('log')
plt.tick_params(axis='y', which='minor')

#plt.setp( ax.get_yticklabels(), visible=True)
ax.yaxis.set_minor_formatter(plt.NullFormatter())
ax.yaxis.set_minor_formatter(plt.FormatStrFormatter("%.2f"))
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%0.2f'))

ax.xaxis.set_major_locator(mlib.ticker.FixedLocator(np.arange(1,20,2)))


# print(ymin, ymax)
ax.set_ylabel('Misclassification',fontsize=20)
ax.set_xlabel('K-Nearest Neighbors',fontsize=20)

ax.tick_params(axis='both', which='major', labelsize=16,  length=4)
ax.tick_params(axis='both', which='minor', labelsize=16, length=4)
plt.grid(which='both')

#plt.savefig('../python_pytorch/results/NeurIPS2021/plots/uci-eeg-misclass.pdf', format='pdf',bbox_inches='tight')

# %%
figure(figsize=(11, 4))
#methods = ['I-SEA', 'I-SEA-Naive', 'Decade', 'Soft-DTW-NN', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
df = pd.DataFrame({'Standard Deviation':np.ravel([std[m] for m in methods]),
                   'Methods':np.ravel([[m]*10 for m in methods]), 
                    'k':np.ravel([np.arange(1,20, 2) for m in methods])})

#sns.set_theme(style="whitegrid")
xlabels_new = [label.replace(' ', '\n') for label in methods]


ax = sns.violinplot(x='Methods', y='Standard Deviation', data=df, palette=color_dict, inner=None, linewidth=0.4, scale='area')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

ax.set_ylabel(ax.get_ylabel(),fontsize=20)
ax.set_xlabel(ax.get_xlabel(),fontsize=20)
ax.set_xticklabels(xlabels_new)
ax.tick_params(axis='both', which='major', labelsize=16,  length=5)
ax.tick_params(axis='both', which='minor', labelsize=16, length=5)
ax.grid(which='major')
ax.set_axisbelow(True)
#plt.setp(ax.collections, alpha=.7)

#plt.savefig('../python_pytorch/results/NeurIPS2021/plots/uci-eeg-violin.pdf', format='pdf',bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-606-da653ac7e9b3> in <module>
#       1 figure(figsize=(11, 4))
#       2 #methods = ['I-SEA', 'I-SEA-Naive', 'Decade', 'Soft-DTW-NN', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
# ----> 3 df = pd.DataFrame({'Standard Deviation':np.ravel([std[m] for m in methods]),
#       4                    'Methods':np.ravel([[m]*10 for m in methods]),
#       5                     'k':np.ravel([np.arange(1,20, 2) for m in methods])})
#
# <ipython-input-606-da653ac7e9b3> in <listcomp>(.0)
#       1 figure(figsize=(11, 4))
#       2 #methods = ['I-SEA', 'I-SEA-Naive', 'Decade', 'Soft-DTW-NN', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
# ----> 3 df = pd.DataFrame({'Standard Deviation':np.ravel([std[m] for m in methods]),
#       4                    'Methods':np.ravel([[m]*10 for m in methods]),
# ...

# %%
tv = {}
#methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
tv['I-SEA (WIS-KDE)'] = [12, 2190]
tv['I-SEA (WIS-Unif)'] = [30, 2384]
tv['Decade'] = [5, 2173]
tv['Soft-DTW'] = [13628, 11394]
tv[ 'MDTW-NN'] = [4679, 4769]
tv['Ma-NN'] = [0, 2517]
tv['MDTW'] = [502, 2261]
tv['GAK'] = [1360, 3125]
tv['MSA'] = [552, 1650]
tv['LDMLT'] = [2, 736]

methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
figure(figsize=(11, 4))
ax = plt.axes()

trials = 20000
tr_tv = []
te_tv = []
xlabels_new = [label.replace(' ', '\n') for label in methods]
for key in methods:
    tr_tv.append(tv[key][0]/200)
    te_tv.append(tv[key][1]/200)
    
N = len(methods)
ind = np.arange(N) 
width = 0.35       
rects1 = ax.bar(ind, tr_tv, width, label='Train')
rects2 = ax.bar(ind + width, te_tv, width,
    label='Test')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,
                '%d' % int(round(float(height))),
                ha='center', va='bottom', fontsize=12)

autolabel(rects1)
autolabel(rects2)

plt.xticks(ind + width / 2, xlabels_new, rotation=45)
plt.legend(loc='best', fontsize=16)
ax.set_ylabel('Percent Triplet Violations',fontsize=20)
ax.set_xlabel('Methods',fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=16,  length=4)
ax.tick_params(axis='both', which='minor', labelsize=16)
ax.grid(which='major')
#plt.savefig('../python_pytorch/results/NeurIPS2021/plots/uci-eeg-tv.pdf', format='pdf',bbox_inches='tight')

# %% [markdown]
# #RAS

# %%
acc = {}
std = {}

# Decade
acc['Decade'] = [0.832, 0.832, 0.838, 0.837, 0.840, 0.838, 0.838, 0.840,  0.838, 0.840 ]
std['Decade'] = [0.030, 0.033, 0.034,  0.031, 0.030, 0.032, 0.028, 0.029, 0.031,  0.028]

# Decade -IS
acc['Decade-ImpS'] = [0.5758745  0.60709601 0.62572036 0.62493135 0.60933024 0.60703664 0.60681193 0.60970921 0.61136813 0.61414977]
std['Decade-ImpS'] = [0.05357727 0.05379892 0.05122564 0.04996271 0.04860467 0.04722855 0.05296821 0.06029976 0.06923178 0.06384703]

# DTW-C MDTW-NN
acc['MDTW-NN'] = [0.915, 0.930, 0.932, 0.928, 0.932, 0.927, 0.928, 0.928, 0.922, 0.925]
std['MDTW-NN'] = [0.026, 0.020, 0.037, 0.036, 0.033, 0.032, 0.019, 0.020, 0.021, 0.018] 

# Manhattan
acc['MaLSTM'] = [0.928, 0.943, 0.937, 0.935,  0.935, 0.935, 0.933, 0.932, 0.928, 0.927]
std['MaLSTM'] = [0.028, 0.024, 0.028, 0.030, 0.025,  0.024, 0.023, 0.024, 0.026, 0.025 ]

# MDTW
acc['MDTW'] = 0.5867    0.5919    0.6089    0.6180    0.6207    0.6380    0.6293    0.6281    0.6270    0.6301
std['MDTW'] = 

# GAK
acc['GAK'] = [0.717, 0.702, 0.677, 0.677, 0.663, 0.638, 0.632, 0.627, 0.608, 0.588]
std['GAK'] = [0.026, 0.036, 0.022, 0.043, 0.037, 0.033, 0.043, 0.030, 0.026, 0.021]

# LDMLT-TS
acc['LDMLT'] = [0.677, 0.613, 0.592, 0.568, 0.542, 0.540, 0.530, 0.523, 0.520, 0.515]
std['LDMLT'] = [0.034, 0.042, 0.059, 0.068, 0.070, 0.068, 0.073, 0.078, 0.074, 0.072]

# Tree-MSA
acc['TMSA'] = [0.680, 0.648, 0.617, 0.583, 0.583, 0.568, 0.567, 0.560, 0.553, 0.542]
std['TMSA'] = [0.037, 0.028, 0.026, 0.026, 0.037, 0.050, 0.044, 0.040, 0.048, 0.033]
# Out:
#   File "<ipython-input-3-4e893b6c7df5>", line 9
#     acc['Decade-ImpS'] = [0.5758745  0.60709601 0.62572036 0.62493135 0.60933024 0.60703664 0.60681193 0.60970921 0.61136813 0.61414977]
#                                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Physio-Net

# %%
acc = {}
std = {}

# Decade
#acc['Decade'] = [0.641, 0.653, 0.650, 0.648, 0.653, 0.651, 0.648, 0.648, 0.647, 0.644]
#std['Decade'] = [0.016, 0.015, 0.009, 0.017, 0.010,	0.010, 0.013, 0.010, 0.012,	0.015]

acc['Decade'] = [0.653, 0.671, 0.668, 0.669, 0.669, 0.667, 0.669, 0.672, 0.670, 0.671]
std['Decade'] = [0.029, 0.024, 0.028, 0.023, 0.028, 0.032, 0.029, 0.032, 0.031,  0.034]
# Decade -IS
#acc['I-SEA'] = [0.67507643, 0.68140312, 0.6823081, 0.68229587, 0.68590763, 0.68140312, 0.68140312, 0.67869634, 0.67959317, 0.68049815]
#std['I-SEA'] = [0.03420112, 0.03107197, 0.03244834, 0.03509067, 0.03922495, 0.0365898, 0.0365898, 0.03985543, 0.03646111, 0.0364766]

# ISEA KDE 49-60-5
#acc['I-SEA'] =  [0.65883576, 0.67327463, 0.67327871, 0.67327463, 0.67596918, 0.67146875, 0.67236965, 0.67147283, 0.67057193, 0.67058008]
#std['I-SEA'] = [0.01116233, 0.00663154, 0.00641535, 0.00961912, 0.01619342, 0.00819768, 0.00883338, 0.00694, 0.00441461, 0.0024487 ]
#round off
acc['I-SEA (WIS-KDE)'] =  [0.659, 0.673, 0.673, 0.673, 0.676, 0.671, 0.672, 0.671, 0.671, 0.671]
std['I-SEA (WIS-KDE)'] = [0.011, 0.007, 0.006, 0.010, 0.016, 0.008, 0.009, 0.007, 0.004, 0.002 ]

#soft-dtw
acc['Soft-DTW'] = [0.622, 0.636, 0.639, 0.638, 0.639, 0.639, 0.638, 0.638, 0.639, 0.638]
std['Soft-DTW'] = [0.046, 0.031, 0.031, 0.032, 0.032, 0.030, 0.033, 0.037, 0.034, 0.034]

#acc['I-SEA-2'] = [0.652, 0.658, 0.658, 0.657, 0.656, 0.656, 0.656, 0.655, 0.657, 0.657]
#std['I-SEA-2'] [0.041, 0.035, 0.031, 0.032,  0.029, 0.027, 0.027, 0.029, 0.027, 0.028]

acc['I-SEA (WIS-Unif)'] = [0.652, 0.666, 0.672, 0.672, 0.672, 0.674, 0.672, 0.668, 0.669, 0.670]
std['I-SEA (WIS-Unif)'] = [0.016,  0.025, 0.026, 0.030, 0.023, 0.021, 0.028, 0.029, 0.028, 0.028]

# DTW-C MDTW-NN
acc['MDTW-NN'] = [ 0.642, 0.648, 0.655,	0.650, 0.643, 0.646, 0.643,	0.643, 0.643, 0.642]
std['MDTW-NN'] = [ 0.032, 0.036, 0.026,	0.023, 0.021, 0.018, 0.020,	0.018, 0.021, 0.019]

# Manhattan
#acc['MaLSTM'] = [0.641,	0.673,	0.660,	0.663,	0.669,	0.665,	0.662,	0.665,	0.667, 0.663]
#std['MaLSTM'] = [0.023,	0.023,	0.030,	0.036,	0.042,	0.037,	0.042,	0.035,	0.031, 0.035]

# Manhattan - NN
acc['Ma-NN'] = [0.641, 0.634, 0.650, 0.648, 0.655, 0.653, 0.653, 0.654, 0.652, 0.650]
std['Ma-NN'] = [0.024, 0.021, 0.019,  0.017, 0.021, 0.022, 0.021,  0.025, 0.025, 0.025]

# Manhattan - LSTM
#acc['Ma-LSTM'] = [0.653, 0.662, 0.666, 0.663, 0.658, 0.661, 0.657, 0.661, 0.663, 0.664]
#std['Ma-LSTM'] = [0.037, 0.034, 0.038, 0.034, 0.034, 0.030, 0.0264, 0.028, 0.026, 0.024]

# MDTW
acc['MDTW'] = [ 0.621, 0.632, 0.643, 0.664, 0.660, 0.652, 0.645, 0.647,	0.650,	0.653]
std['MDTW'] = [ 0.015, 0.020, 0.030, 0.030,	0.040, 0.035, 0.048, 0.039,	0.040,	0.029]

# GAK
acc['GAK'] = [ 0.613, 0.633, 0.648, 0.655, 0.654, 0.649, 0.649, 0.644,	0.650,	0.648]
std['GAK'] = [ 0.012, 0.023, 0.022,	0.031, 0.041, 0.033, 0.040,	0.027,	0.030,	0.035]

# LDMLT-TS
acc['LDMLT'] = [ 0.632, 0.646,	0.649,	0.650,	0.668,	0.673,	0.668,	0.679,	0.678,	0.674]
std['LDMLT'] = [ 0.015,	0.033,	0.033,	0.036,	0.024,	0.015,	0.025,	0.027,	0.021,	0.025]

# Tree-MSA
acc['MSA'] = [ 0.622, 0.631, 0.645, 0.662,	0.660,	0.649, 0.644, 0.650, 0.651, 0.652]
std['MSA'] = [ 0.012, 0.022, 0.026, 0.030,	0.038,	0.039, 0.049, 0.038, 0.0453, 0.034]

# %%
res_line = ''
met = 'I-SEA (WIS-Unif)'
for i in range(0,10):
    res_line = res_line + ' & $ ' + str(acc[met][i]) + ' \pm ' + str(std[met][i]) + ' $ ' 
print(res_line)
# Out:
#  & $ 0.652 \pm 0.016 $  & $ 0.666 \pm 0.025 $  & $ 0.672 \pm 0.026 $  & $ 0.672 \pm 0.03 $  & $ 0.672 \pm 0.023 $  & $ 0.674 \pm 0.021 $  & $ 0.672 \pm 0.028 $  & $ 0.668 \pm 0.029 $  & $ 0.669 \pm 0.028 $  & $ 0.67 \pm 0.028 $

# %%
import matplotlib.ticker as mtick
from matplotlib import pyplot
import matplotlib as mlib
from matplotlib.pyplot import figure
#methods = ['I-SEA','Decade', 'MDTW-NN', 'MaLSTM', 'MDTW', 'GAK', 'TMSA','LDMLT']
methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
marker = itertools.cycle(("<", "o", "v", "s", "D", "X", "d", "*","h", "x","+","P","H", '^', ">")) 
lstyle = itertools.cycle(('--', '-.', ':'))
lcolor = itertools.cycle(('black', 'red', 'cyan', 'magenta', 'brown', 'lime', 'blue', 'green', 'orange', 'purple', 'darkblue'))
figure(figsize=(11, 6))
color_dict = {}
ax = plt.axes()
i = 1
for key in methods:
    val = 0.5*np.random.rand(1)
    cl = next(lcolor)
    if cl == 'black':
        color_dict[key] = 'gray'
    else:
        color_dict[key] = cl
    ax.semilogy(np.arange(1,20, 2),(1 - np.array(acc[key])), marker = next(marker), 
             linestyle=next(lstyle), linewidth=2, markersize=10, color=cl)#color=str(val.item()))
    #if key == 'I-SEA' or key == 'Decade' or key == 'LDMLT':
    #    ax.fill_between(np.arange(1,20, 2), (1 - np.array(acc[key]))-std[key], (1 - np.array(acc[key]))+std[key], alpha = 0.6 - 0.15*i, color=cl)
    #    i = i + 1

ax.legend(methods, loc='center left', bbox_to_anchor= (1, 0.64), fontsize=16)

ax.set_yscale('log')
plt.tick_params(axis='y', which='minor')

#plt.setp( ax.get_yticklabels(), visible=True)
ax.yaxis.set_minor_formatter(plt.NullFormatter())
ax.yaxis.set_minor_formatter(plt.FormatStrFormatter("%.2f"))
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%0.2f'))

ax.xaxis.set_major_locator(mlib.ticker.FixedLocator(np.arange(1,20,2)))


# print(ymin, ymax)
ax.set_ylabel('Misclassification',fontsize=20)
ax.set_xlabel('K-Nearest Neighbors',fontsize=20)

ax.tick_params(axis='both', which='major', labelsize=16,  length=4)
ax.tick_params(axis='both', which='minor', labelsize=16, length=4)
plt.grid(which='both')

#plt.savefig('../python_pytorch/results/NeurIPS2021/plots/physio-net-misclass.pdf', format='pdf',bbox_inches='tight')

# %%
figure(figsize=(11, 4))
#methods = ['I-SEA', 'I-SEA-Naive', 'Decade', 'Soft-DTW-NN', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
df = pd.DataFrame({'Standard Deviation':np.ravel([std[m] for m in methods]),
                   'Methods':np.ravel([[m]*10 for m in methods]), 
                    'k':np.ravel([np.arange(1,20, 2) for m in methods])})

xlabels_new = [label.replace(' ', '\n') for label in methods]
#sns.set_theme(style="whitegrid")

ax = sns.violinplot(x='Methods', y='Standard Deviation', data=df, palette=color_dict, inner=None, linewidth=0.4)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

ax.set_ylabel(ax.get_ylabel(),fontsize=20)
ax.set_xlabel(ax.get_xlabel(),fontsize=20)
ax.set_xticklabels(xlabels_new)
ax.tick_params(axis='both', which='major', labelsize=16,  length=4)
ax.tick_params(axis='both', which='minor', labelsize=16, length=4)
ax.grid(which='major')
ax.set_axisbelow(True)
#plt.setp(ax.collections, alpha=.7)

#plt.savefig('../python_pytorch/results/NeurIPS2021/plots/physio-net-violin.pdf', format='pdf',bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-605-2c5c0fa8f3a4> in <module>
#       1 figure(figsize=(11, 4))
#       2 #methods = ['I-SEA', 'I-SEA-Naive', 'Decade', 'Soft-DTW-NN', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
# ----> 3 df = pd.DataFrame({'Standard Deviation':np.ravel([std[m] for m in methods]),
#       4                    'Methods':np.ravel([[m]*10 for m in methods]),
#       5                     'k':np.ravel([np.arange(1,20, 2) for m in methods])})
#
# <ipython-input-605-2c5c0fa8f3a4> in <listcomp>(.0)
#       1 figure(figsize=(11, 4))
#       2 #methods = ['I-SEA', 'I-SEA-Naive', 'Decade', 'Soft-DTW-NN', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
# ----> 3 df = pd.DataFrame({'Standard Deviation':np.ravel([std[m] for m in methods]),
#       4                    'Methods':np.ravel([[m]*10 for m in methods]),
# ...

# %%
# Physio-data


tv = {}
#methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
tv['I-SEA (WIS-KDE)'] = [546, 3271]
tv['I-SEA (WIS-Unif)'] = [712, 3431]
tv['Decade'] = [845, 3503]
tv['Soft-DTW'] = [12377, 9215]
tv[ 'MDTW-NN'] = [5104, 4942]
tv['Ma-NN'] = [1, 2067]
tv['MDTW'] = [474, 2788] 
tv['GAK'] = [561, 3012]
tv['MSA'] = [457, 2764]
tv['LDMLT'] = [120, 1450]


methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
figure(figsize=(11, 4))
ax = plt.axes()

trials = 20000
tr_tv = []
te_tv = []
xlabels_new = [label.replace(' ', '\n') for label in methods]
for key in methods:
    tr_tv.append(tv[key][0]/200)
    te_tv.append(tv[key][1]/200)
    
N = len(methods)
ind = np.arange(N) 
width = 0.35       
rects1 = ax.bar(ind, tr_tv, width, label='Train')
rects2 = ax.bar(ind + width, te_tv, width,
    label='Test')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.0*height,
                '%d' % int(round(float(height))),
                ha='center', va='bottom', fontsize=12)

autolabel(rects1)
autolabel(rects2)

plt.xticks(ind + width / 2, xlabels_new, rotation=45)
plt.legend(loc='best', fontsize=16)
ax.set_ylabel('Percent Triplet Violations',fontsize=20)
ax.set_xlabel('Methods',fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=16,  length=4)
ax.tick_params(axis='both', which='minor', labelsize=16)
ax.grid(which='major')

#plt.savefig('../python_pytorch/results/NeurIPS2021/plots/physio-net-tv.pdf', format='pdf',bbox_inches='tight')

# %%
# import matplotlib.ticker as mtick
# from matplotlib import pyplot
# import matplotlib as mlib
# #methods = ['I-SEA','Decade', 'MDTW-NN', 'MaLSTM', 'MDTW', 'GAK', 'TMSA','LDMLT']
# methods = ['I-SEA','Decade', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
# marker = itertools.cycle(("<", "o", "v", "s", "D", "X", "d", "*","h", "x","+","P","H", '^', ">")) 
# lstyle = itertools.cycle(('--', '-.', ':'))
# lcolor = itertools.cycle(('black', 'red', 'cyan', 'magenta', 'brown', 'lime', 'blue', 'green'))

# ax = plt.axes()

# for key in methods:
#     val = 0.5*np.random.rand(1)
#     ax.semilogy(np.arange(1,20, 2set_axisbelow(True)),(1 - np.array(acc[key])), marker = next(marker), 
#              linestyle=next(lstyle), linewidth=2, markersize=8, color=next(lcolor))#color=str(val.item()))
# ax.legend(methods, loc='center left', bbox_to_anchor= (1.0, 0.72))

# ax.set_yscale('log')
# plt.tick_params(axis='y', which='minor')

# #plt.setp( ax.get_yticklabels(), visible=True)
# ax.yaxis.set_minor_formatter(plt.NullFormatter())
# ax.yaxis.set_minor_formatter(plt.FormatStrFormatter("%.2f"))
# ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%0.2f'))

# ax.xaxis.set_major_locator(mlib.ticker.FixedLocator(np.arange(1,20,2)))


# # print(ymin, ymax)
# ax.set_ylabel('Misclassification',fontsize=14)
# ax.set_xlabel('K-Nearest Neighbors',fontsize=14)

# ax.tick_params(axis='both', which='major', labelsize=12,  length=4)
# ax.tick_params(axis='both', which='minor', labelsize=12, length=4)
# plt.grid(which='both')

# #plt.savefig('../python_pytorch/results/physio-data/plots/physio_net_misclass_updated_Feb_3.pdf', format='pdf',bbox_inches='tight')

# %% [markdown]
# ## Synthetic 100 20

# %%
acc = {}
std = {}
# Status: 
# run Ma-NN (set-to-run)
# Ma-LSTM (set to run)


#decade (set to run)
acc['Decade'] = [0.976, 0.991, 0.993, 0.995, 0.993, 0.993, 0.993, 0.993, 0.993, 0.995]
std['Decade'] =  [0.013, 0.005, 0.006,  0.004, 0.003, 0.003, 0.006, 0.006, 0.006, 0.007]


acc['I-SEA (WIS-KDE)'] = [0.985, 0.992, 0.992, 0.995, 0.995, 0.993, 0.995, 0.995, 0.995, 0.993]
std['I-SEA (WIS-KDE)'] = [0.006, 0.005, 0.005, 0.004, 0.006, 0.006, 0.006, 0.006, 0.006, 0.006]

 

#acc['I-SEA-Naive'] = [0.983, 0.993, 0.993, 0.996, 0.996, 0.995, 0.995, 0.993, 0.996, 0.995]
#std['I-SEA-Naive'] =  [0.005, 0.008, 0.008, 0.004, 0.004, 0.007,0.007, 0.003, 0.004, 0.007]

acc['I-SEA (WIS-Unif)'] =  [0.978, 0.991, 0.988, 0.990, 0.990, 0.991, 0.99, 0.991, 0.993, 0.990]
std['I-SEA (WIS-Unif)'] =  [0.013, 0.009, 0.006, 0.008, 0.008, 0.005, 0.006,  0.005, 0.006,  0.006]


# DTW-C MDTW-NN 
acc['MDTW-NN'] = [0.956, 0.968, 0.976, 0.971, 0.976, 0.983, 0.981, 0.983, 0.985, 0.986]
std['MDTW-NN'] = [0.012, 0.013, 0.014, 0.017, 0.021, 0.022, 0.021, 0.022, 0.019, 0.016]


# Manhattan
#acc['MaLSTM'] = [0.641,	0.673,	0.660,	0.663,	0.669,	0.665,	0.662,	0.665,	0.667, 0.663]
#std['MaLSTM'] = [0.023,	0.023,	0.030,	0.036,	0.042,	0.037,	0.042,	0.035,	0.031, 0.035]

#acc['Ma-NN'] = 
#std['Ma-NN'] = 


#Soft-DTW
acc['Soft-DTW'] = [0.648, 0.748, 0.755, 0.761, 0.753, 0.755, 0.763, 0.766, 0.755, 0.766]
std['Soft-DTW'] = [0.142, 0.068, 0.065, 0.053, 0.062, 0.062, 0.060, 0.048, 0.056, 0.069]

# MDTW
acc['MDTW'] = [0.970, 0.985, 0.986, 0.985, 0.988, 0.993, 0.995, 0.996, 0.996, 0.996]
std['MDTW'] = [0.009, 0.014, 0.007, 0.003, 0.004, 0.006, 0.007, 0.007, 0.004, 0.004]

# GAK
acc['GAK'] = [0.985, 0.986, 0.986, 0.990, 0.991, 0.986, 0.985, 0.990, 0.990, 0.986]
std['GAK'] = [0.010, 0.011, 0.016, 0.013, 0.010, 0.012, 0.012, 0.006, 0.009, 0.012]

# LDMLT-TS
acc['LDMLT'] = [0.958, 0.971, 0.975, 0.983, 0.991, 0.991, 0.995, 0.995, 0.993, 0.995]
std['LDMLT'] = [0.014, 0.012, 0.008, 0.011, 0.008, 0.011, 0.007, 0.007, 0.006, 0.007]

# Tree-MSA
acc['MSA'] = [0.910, 0.958, 0.968, 0.970, 0.975, 0.978, 0.980, 0.981, 0.978, 0.981]
std['MSA'] = [0.025, 0.024, 0.013, 0.018, 0.024, 0.021, 0.022, 0.024, 0.024, 0.024]

# %%
import matplotlib.ticker as mtick
from matplotlib import pyplot
import matplotlib as mlib
from matplotlib.pyplot import figure


#methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'MDTW-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
skip_methods = ['Soft-DTW', 'Ma-NN']
methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
marker = itertools.cycle(("<", "o", "v", "s", "D", "X", "d", "*","h", "x","+","P","H", '^', ">")) 
lstyle = itertools.cycle(('--', '-.', ':'))
lcolor = itertools.cycle(('black', 'red', 'cyan', 'magenta', 'brown', 'lime', 'blue', 'green', 'orange', 'purple', 'darkblue'))
figure(figsize=(11, 6))
color_dict = {}
ax = plt.axes()
i = 1
for key in methods:
    val = 0.5*np.random.rand(1)
    cl = next(lcolor)
    ms = next(marker)
    ls = next(lstyle)
    if cl == 'black':
        color_dict[key] = 'gray'
    else:
        color_dict[key] = cl
    if key not in skip_methods:  
    
        ax.semilogy(np.arange(1,20, 2),(1 - np.array(acc[key])), marker = ms, 
             linestyle=ls, linewidth=2, markersize=10, color=cl)#color=str(val.item()))

new_methods = [x for x in methods if x not in skip_methods]

ax.legend(methods, loc='center left', bbox_to_anchor= (1, 0.71), fontsize=16)

ax.set_yscale('log')
plt.tick_params(axis='y', which='minor')

#plt.setp( ax.get_yticklabels(), visible=True)
ax.yaxis.set_minor_formatter(plt.NullFormatter())
ax.yaxis.set_minor_formatter(plt.FormatStrFormatter("%.2f"))
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%0.2f'))

ax.xaxis.set_major_locator(mlib.ticker.FixedLocator(np.arange(1,20,2)))


# print(ymin, ymax)
ax.set_ylabel('Misclassification',fontsize=20)
ax.set_xlabel('K-Nearest Neighbors',fontsize=20)

ax.tick_params(axis='both', which='major', labelsize=16,  length=4)
ax.tick_params(axis='both', which='minor', labelsize=16, length=4)
plt.grid(which='both')

#plt.savefig('../python_pytorch/results/NeurIPS2021/plots/syn-data-100-20-misclass.pdf', format='pdf',bbox_inches='tight')

# %%
figure(figsize=(11, 6))
#methods = ['I-SEA', 'I-SEA-Naive', 'Decade', 'Soft-DTW-NN', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
df = pd.DataFrame({'Standard Deviation':np.ravel([std[m] for m in new_methods]),
                   'Methods':np.ravel([[m]*10 for m in new_methods]), 
                    'k':np.ravel([np.arange(1,20, 2) for m in new_methods])})

#sns.set_theme(style="whitegrid")
xlabels_new = [label.replace(' ', '\n') for label in new_methods]

ax = sns.violinplot(x='Methods', y='Standard Deviation', data=df, palette=color_dict, inner=None, linewidth=0.4)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')


ax.set_ylabel(ax.get_ylabel(),fontsize=20)
ax.set_xlabel(ax.get_xlabel(),fontsize=20)
ax.set_xticklabels(xlabels_new)
ax.tick_params(axis='both', which='major', labelsize=16,  length=4)
ax.tick_params(axis='both', which='minor', labelsize=16)
ax.grid(which='major')

ax.set_axisbelow(True)
#plt.setp(ax.collections, alpha=.7)

#plt.savefig('../python_pytorch/results/NeurIPS2021/plots/syn-data-100-20-violin.pdf', format='pdf',bbox_inches='tight')

# %%
for key in new_methods:
    res_line = key
    met = 'I-SEA (WIS-Unif)'
    for i in range(0,10):
        res_line = res_line + ' & $ ' + str(acc[key][i]) + ' \pm ' + str(std[key][i]) + ' $ ' 
    print(res_line)
# Out:
# I-SEA (WIS-KDE) & $ 0.985 \pm 0.006 $  & $ 0.992 \pm 0.005 $  & $ 0.992 \pm 0.005 $  & $ 0.995 \pm 0.004 $  & $ 0.995 \pm 0.006 $  & $ 0.993 \pm 0.006 $  & $ 0.995 \pm 0.006 $  & $ 0.995 \pm 0.006 $  & $ 0.995 \pm 0.006 $  & $ 0.993 \pm 0.006 $
# I-SEA (WIS-Unif) & $ 0.978 \pm 0.013 $  & $ 0.991 \pm 0.009 $  & $ 0.988 \pm 0.006 $  & $ 0.99 \pm 0.008 $  & $ 0.99 \pm 0.008 $  & $ 0.991 \pm 0.005 $  & $ 0.99 \pm 0.006 $  & $ 0.991 \pm 0.005 $  & $ 0.993 \pm 0.006 $  & $ 0.99 \pm 0.006 $
# Decade & $ 0.976 \pm 0.013 $  & $ 0.991 \pm 0.005 $  & $ 0.993 \pm 0.006 $  & $ 0.995 \pm 0.004 $  & $ 0.993 \pm 0.003 $  & $ 0.993 \pm 0.003 $  & $ 0.993 \pm 0.006 $  & $ 0.993 \pm 0.006 $  & $ 0.993 \pm 0.006 $  & $ 0.995 \pm 0.007 $
# MDTW-NN & $ 0.956 \pm 0.012 $  & $ 0.968 \pm 0.013 $  & $ 0.976 \pm 0.014 $  & $ 0.971 \pm 0.017 $  & $ 0.976 \pm 0.021 $  & $ 0.983 \pm 0.022 $  & $ 0.981 \pm 0.021 $  & $ 0.983 \pm 0.022 $  & $ 0.985 \pm 0.019 $  & $ 0.986 \pm 0.016 $
# ...

# %%
#Triplet Violations

# %%
# Physio-data


tv = {}
#methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
tv['I-SEA (WIS-KDE)'] = [546, 3271]
tv['I-SEA (WIS-Unif)'] = [712, 3431]
tv['Decade'] = [845, 3503]
tv['Soft-DTW'] = [12377, 9215]
tv[ 'MDTW-NN'] = [5104, 4942]
tv['Ma-NN'] = [1, 2067]
tv['MDTW'] = [474, 2788] 
tv['GAK'] = [561, 3012]
tv['MSA'] = [457, 2764]
tv['LDMLT'] = [120, 1450]

methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
marker = itertools.cycle(("<", "o", "v", "s", "D", "X", "d", "*","h", "x","+","P","H", '^', ">")) 
lstyle = itertools.cycle(('--', '-.', ':'))
lcolor = itertools.cycle(('black', 'red', 'cyan', 'magenta', 'brown', 'lime', 'blue', 'green', 'orange', 'purple', 'darkblue'))
figure(figsize=(11, 6))
color_dict = {}
ax = plt.axes()
i = 1
trials = 20000
tr_tv = []
te_tv = []
xlabels_new = [label.replace(' ', '\n') for label in methods]
for key in methods:
    tr_tv.append(tv[key][0]/200)
    te_tv.append(tv[key][1]/200)
    
N = len(methods)
ind = np.arange(N) 
width = 0.35       
ax.bar(ind, tr_tv, width, label='Train')
ax.bar(ind + width, te_tv, width,
    label='Test')

plt.xticks(ind + width / 2, xlabels_new, rotation=45)
plt.legend(loc='best', fontsize=16)
ax.set_ylabel('Percent Triplet Violations',fontsize=20)
ax.set_xlabel('Methods',fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=16,  length=4)
ax.tick_params(axis='both', which='minor', labelsize=16)
ax.grid(which='major')

# %%
methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
marker = itertools.cycle(("<", "o", "v", "s", "D", "X", "d", "*","h", "x","+","P","H", '^', ">")) 
lstyle = itertools.cycle(('--', '-.', ':'))
lcolor = itertools.cycle(('black', 'red', 'cyan', 'magenta', 'brown', 'lime', 'blue', 'green', 'orange', 'purple', 'darkblue'))
figure(figsize=(11, 6))
color_dict = {}
ax = plt.axes()
i = 1
trials = 20000
tr_tv = []
te_tv = []
xlabels_new = [label.replace(' ', '\n') for label in methods]
for key in methods:
    tr_tv.append(tv[key][0]/200)
    te_tv.append(tv[key][1]/200)
    
N = len(methods)
ind = np.arange(N) 
width = 0.35       
ax.bar(ind, tr_tv, width, label='Train')
ax.bar(ind + width, te_tv, width,
    label='Test')

plt.xticks(ind + width / 2, xlabels_new, rotation=45)
plt.legend(loc='best', fontsize=16)
ax.set_ylabel('Percent Triplet Violations',fontsize=20)
ax.set_xlabel('Methods',fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=16,  length=4)
ax.tick_params(axis='both', which='minor', labelsize=16)
ax.grid(which='major')
#ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %%
# UCI



tv = {}
#methods = ['I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Decade', 'Soft-DTW', 'MDTW-NN', 'Ma-NN', 'MDTW', 'GAK', 'MSA','LDMLT']
tv['I-SEA (WIS-KDE)'] = [12, 2190]
tv['I-SEA (WIS-Unif)'] = [30, 2384]
tv['Decade'] = [5, 2173]
tv['Soft-DTW'] = [13628, 11394]
tv[ 'MDTW-NN'] = [4679, 4769]
tv['Ma-NN'] = [0, 2517]
tv['MDTW'] = [502, 2261]
tv['GAK'] = [1360, 3125]
tv['MSA'] = [552, 1650]
tv['LDMLT'] = [2, 736]

# %%
from scipy.io import loadmat
import numpy as np
import h5py
import matplotlib.pyplot as plt


m = 1
d = 1
trials = 20000
#method = ['DTW_C', 'Manhattan', 'Decade', 'I-SEA (WIS-KDE)', 'I-SEA (WIS-Unif)', 'Soft-DTW']
#method = ['EDISTNew_C_32_48_10_hid_1_res', '1_EDISTkdeIS_C_32_48_10_hid_1_iter_5_res', 'EDISTisNew_C_32_48_10_hid_1_res', 'soft-dtw_hid_1_res']
method = ['EDISTNew_C_49_60_5_hid_1_res', 'EDISTisNewKDE_C_49_60_5_hid_1_iter_5_res', 'EDISTisNew_C_49_60_5_hid_1_res', 'soft-dtw_hid_1_res']

data_name = ['uci-eeg', 'physio-data']
#data_name = ['ucieeg-new', 'physio-data']

#file_dist = '../python_pytorch/results/'+ data_name[d] + '/run_jupyter/' + data_name[d] + '-' + method[m] + '-' + 'res_hid_0_5.mat'
#file_dist = '../python_pytorch/results/'+ data_name[d] + '/run_jupyter/' + method[m] + '_' + 'hid_0.5_res.mat'
file_dist = '../python_pytorch/results/NeurIPS2021/'+ data_name[d] + '/run_jupyter/' + method[m] + '.mat'

#f = h5py.File(file_dist, 'r')
f = loadmat(file_dist)

arrays = {}
for k, v in f.items():
    arrays[k] = np.array(v)
    
    
dist_tr_tr = f['distTrTr'][0][4]
dist_tr_te = f['distTeTr'][0][4]

#dist_tr_tr = f['distTrTr'][4]
#dist_tr_te = f['distTeTr'][4]

print('Train violations')

id_list = range(0,dist_tr_tr.shape[0])
triplet_violation = 0
for t in range(0, trials):
    sel_ids =np.random.choice(id_list, size=3, replace=False)
    i, j, k = sel_ids
    if dist_tr_tr[i,j] > dist_tr_tr[j,k] + dist_tr_tr[i,k] : 
        triplet_violation = triplet_violation + 1

print(data_name[d], method[m])
print(triplet_violation, (triplet_violation/trials)*100)

print('Test Violations')

id_list = range(0,dist_tr_te.shape[0])
triplet_violation = 0
for t in range(0, trials):
    sel_ids =np.random.choice(id_list, size=3, replace=False)
    i, j, k = sel_ids
    if dist_tr_te[i,j] > dist_tr_te[j,k] + dist_tr_te[i,k] : 
        triplet_violation = triplet_violation + 1

print(data_name[d], method[m])
print(triplet_violation, (triplet_violation/trials)*100)
# Out:
# Train violations
# physio-data EDISTisNewKDE_C_49_60_5_hid_1_iter_5_res
# 581 2.905
# Test Violations
# physio-data EDISTisNewKDE_C_49_60_5_hid_1_iter_5_res
# 3216 16.08

# %%
dist_tr_tr = f['distTeTr'][4]
